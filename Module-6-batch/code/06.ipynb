# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .master("spark://localhost:7077") \
    .appName('test') \
    .config("spark.executor.memory", "1g") \
    .config("spark.cores.max", "4") \
    .getOrCreate()
# Out:
# 26/03/11 13:26:49 ERROR TaskSchedulerImpl: Lost executor 1 on 172.19.0.3: Worker shutting down
# 26/03/11 13:26:49 ERROR TaskSchedulerImpl: Lost executor 0 on 172.19.0.4: Worker shutting down
# 26/03/11 13:26:50 WARN StandaloneAppClient$ClientEndpoint: Connection to 172.19.0.2:7077 failed; waiting for master to reconnect...
# 26/03/11 13:26:50 WARN StandaloneSchedulerBackend: Disconnected from Spark cluster! Waiting for reconnection...
